# %%
import pandas as pd
import ta

# %%
df = pd.read_csv('C:/Users/ETOUNDI/Downloads/FETUSD.csv')
df
# Out:
#       Unnamed: 0            timestamp     open    close     high      low  \
# 0              0  2024-10-22 17:00:00  1.34490  1.34510  1.34510  1.34490
# 1              1  2024-10-22 16:00:00  1.34990  1.33920  1.34990  1.33810
# 2              2  2024-10-22 15:00:00  1.36230  1.35950  1.36230  1.35580
# 3              3  2024-10-22 14:00:00  1.35160  1.36400  1.36820  1.35160
# 4              4  2024-10-22 13:00:00  1.35440  1.34750  1.38050  1.34000
# ...          ...                  ...      ...      ...      ...      ...
# 9995        9995  2023-08-26 10:00:00  0.20777  0.20811  0.20811  0.20777
# 9996        9996  2023-08-26 09:00:00  0.20806  0.20816  0.20816  0.20806
# 9997        9997  2023-08-26 08:00:00  0.20850  0.20866  0.20866  0.20817
# 9998        9998  2023-08-26 07:00:00  0.20897  0.20914  0.20914  0.20833
# 9999        9999  2023-08-26 06:00:00  0.20949  0.20974  0.21009  0.20949
#
#            volume
# 0      663.845042
# 1     1198.703534
# 2       15.671524
# ...

# %%
df2 = ta.wrapper.add_volatility_ta(df,close='close',high='high',low='low')

# %%
df2
# Out:
#       Unnamed: 0            timestamp     open    close     high      low  \
# 0              0  2024-10-22 17:00:00  1.34490  1.34510  1.34510  1.34490
# 1              1  2024-10-22 16:00:00  1.34990  1.33920  1.34990  1.33810
# 2              2  2024-10-22 15:00:00  1.36230  1.35950  1.36230  1.35580
# 3              3  2024-10-22 14:00:00  1.35160  1.36400  1.36820  1.35160
# 4              4  2024-10-22 13:00:00  1.35440  1.34750  1.38050  1.34000
# ...          ...                  ...      ...      ...      ...      ...
# 9995        9995  2023-08-26 10:00:00  0.20777  0.20811  0.20811  0.20777
# 9996        9996  2023-08-26 09:00:00  0.20806  0.20816  0.20816  0.20806
# 9997        9997  2023-08-26 08:00:00  0.20850  0.20866  0.20866  0.20817
# 9998        9998  2023-08-26 07:00:00  0.20897  0.20914  0.20914  0.20833
# 9999        9999  2023-08-26 06:00:00  0.20949  0.20974  0.21009  0.20949
#
#            volume    volume_adi    volume_obv  volume_cmf  ...  \
# ...
